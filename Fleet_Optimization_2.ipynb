# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2023.7.22)

# %%
import folium
from folium import plugins

# %%
# Latitude and longitude for the initial map center
initial_lat = 40.819688
initial_lon = -73.915091

# Create a map with the initial center and zoom level
m = folium.Map(location=[initial_lat, initial_lon], zoom_start=10)

# %%
from IPython.display import display

def create_map_with_labels(latitudes, longitudes, labels, initial_center=None, zoom_level=10):
    """
    Create a folium map with labeled markers for given latitudes, longitudes, and labels.

    Parameters:
        latitudes (list): List of latitude values.
        longitudes (list): List of longitude values.
        labels (list): List of labels corresponding to each point.
        initial_center (tuple): Initial center coordinates in the format (latitude, longitude).
                               If not provided, the center will be calculated based on input coordinates.
        zoom_level (int): Initial zoom level of the map.

    Returns:
        folium.Map: A folium map with labeled markers.
    """
    if initial_center is None:
        # Calculate the center as the mean of all input coordinates
        initial_center = (sum(latitudes) / len(latitudes), sum(longitudes) / len(longitudes))

    # Create the map
    m = folium.Map(location=initial_center, zoom_start=zoom_level)

    # Add markers with custom labels for each latitude and longitude
    for lat, lon, label in zip(latitudes, longitudes, labels):
        folium.Marker([lat, lon], tooltip=label).add_to(m)

    return m

# %%
# List of latitudes and longitudes

latitudes = [40.815421, 40.764198, 40.768790, 40.734851, 40.743613, 40.745313, 40.662713, 40.703761, 40.713620, 40.725212]
longitudes = [-73.941761, -73.910785, -73.953285, -73.952950, -73.977998, -73.993793, -73.946101, -73.886496, -73.943076, -73.809179]
labels = ["L1","L2","L3","L4","L5","L6","L7","L8","L9","L10","L11"]

map_with_labels = create_map_with_labels(latitudes, longitudes, labels)
display(map_with_labels)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7baf9bcf887f155325cca53ecf5bad6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7baf9bcf887f155325cca53ecf5bad6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7baf9bcf887f155325cca53ecf5bad6 = L.map(
#                 &quot;map_e7baf9bcf887f155325cca53ecf5bad6&quot;,
#                 {
#                     center: [40.7377492, -73.93154239999998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fa645a43126c641972260425c93528e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e7baf9bcf887f155325cca53ecf5bad6);
#
#
#             var marker_2515fd39f43d5d7a41e1b32e30a37820 = L.marker(
#                 [40.815421, -73.941761],
#                 {}
#             ).addTo(map_e7baf9bcf887f155325cca53ecf5bad6);
#
#
#             marker_2515fd39f43d5d7a41e1b32e30a37820.bindTooltip(
#                 `&lt;div&gt;
#                      L1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8c655c2670e22799ef628e6dd2ca9cd0 = L.marker(
#                 [40.764198, -73.910785],
#                 {}
#             ).addTo(map_e7baf9bcf887f155325cca53ecf5bad6);
#
#
#             marker_8c655c2670e22799ef628e6dd2ca9cd0.bindTooltip(
#                 `&lt;div&gt;
#                      L2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ba5689ac8c0e249ecf865dca21547fd8 = L.marker(
#                 [40.76879, -73.953285],
#                 {}
#             ).addTo(map_e7baf9bcf887f155325cca53ecf5bad6);
#
#
#             marker_ba5689ac8c0e249ecf865dca21547fd8.bindTooltip(
#                 `&lt;div&gt;
#                      L3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_08450909b6c21c463c9d94f45bb881fd = L.marker(
#                 [40.734851, -73.95295],
#                 {}
#             ).addTo(map_e7baf9bcf887f155325cca53ecf5bad6);
#
#
#             marker_08450909b6c21c463c9d94f45bb881fd.bindTooltip(
#                 `&lt;div&gt;
#                      L4
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c10312a979acb1c27019378b3f364e61 = L.marker(
#                 [40.743613, -73.977998],
#                 {}
#             ).addTo(map_e7baf9bcf887f155325cca53ecf5bad6);
#
#
#             marker_c10312a979acb1c27019378b3f364e61.bindTooltip(
#                 `&lt;div&gt;
#                      L5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_89e540c440c2e6554d7a0f8ab7af5206 = L.marker(
#                 [40.745313, -73.993793],
#                 {}
#             ).addTo(map_e7baf9bcf887f155325cca53ecf5bad6);
#
#
#             marker_89e540c440c2e6554d7a0f8ab7af5206.bindTooltip(
#                 `&lt;div&gt;
#                      L6
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6b908c9f38cf0c39d317e024448df491 = L.marker(
#                 [40.662713, -73.946101],
#                 {}
#             ).addTo(map_e7baf9bcf887f155325cca53ecf5bad6);
#
#
#             marker_6b908c9f38cf0c39d317e024448df491.bindTooltip(
#                 `&lt;div&gt;
#                      L7
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_11b96acc31343b72765cca575c4e93c7 = L.marker(
#                 [40.703761, -73.886496],
#                 {}
#             ).addTo(map_e7baf9bcf887f155325cca53ecf5bad6);
#
#
#             marker_11b96acc31343b72765cca575c4e93c7.bindTooltip(
#                 `&lt;div&gt;
#                      L8
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ffaa2f09768a0d32084d4537bebeec7a = L.marker(
#                 [40.71362, -73.943076],
#                 {}
#             ).addTo(map_e7baf9bcf887f155325cca53ecf5bad6);
#
#
#             marker_ffaa2f09768a0d32084d4537bebeec7a.bindTooltip(
#                 `&lt;div&gt;
#                      L9
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_79eafc2423e1b1bcf8cad067c10e478a = L.marker(
#                 [40.725212, -73.809179],
#                 {}
#             ).addTo(map_e7baf9bcf887f155325cca53ecf5bad6);
#
#
#             marker_79eafc2423e1b1bcf8cad067c10e478a.bindTooltip(

# %%
def create_map_with_lines(latitudes, longitudes, labels, initial_center=None, zoom_level=10):
    """
    Create a folium map with labeled markers and lines connecting them.

    Parameters:
        latitudes (list): List of latitude values.
        longitudes (list): List of longitude values.
        labels (list): List of labels corresponding to each point.
        initial_center (tuple): Initial center coordinates in the format (latitude, longitude).
                               If not provided, the center will be calculated based on input coordinates.
        zoom_level (int): Initial zoom level of the map.

    Returns:
        folium.Map: A folium map with labeled markers and lines.
    """
    if initial_center is None:
        # Calculate the center as the mean of all input coordinates
        initial_center = (sum(latitudes) / len(latitudes), sum(longitudes) / len(longitudes))

    # Create the map
    m = folium.Map(location=initial_center, zoom_start=zoom_level)

    # Add markers with custom labels for each latitude and longitude
    for lat, lon, label in zip(latitudes, longitudes, labels):
        folium.Marker([lat, lon], tooltip=label).add_to(m)

    # Add lines connecting the points
    for i in range(len(latitudes) - 1):
        points = [[latitudes[i], longitudes[i]], [latitudes[i + 1], longitudes[i + 1]]]
        folium.PolyLine(points, color="blue").add_to(m)

    return m

# %%
# List of latitudes and longitudes

latitudes = [40.819688, 40.815421, 40.764198, 40.768790, 40.734851, 40.743613, 40.745313, 40.662713, 40.703761, 40.713620, 40.725212]
longitudes = [-73.915091, -73.941761, -73.910785, -73.953285, -73.952950, -73.977998, -73.993793, -73.946101, -73.886496, -73.943076, -73.809179]
labels = ["L1","L2","L3","L4","L5","L6","L7","L8","L9","L10","L11"]

map_with_lines = create_map_with_lines(latitudes, longitudes, labels)
display(map_with_lines)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85f959f37e30a5e67db47d91ad35b3df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85f959f37e30a5e67db47d91ad35b3df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85f959f37e30a5e67db47d91ad35b3df = L.map(
#                 &quot;map_85f959f37e30a5e67db47d91ad35b3df&quot;,
#                 {
#                     center: [40.745198181818175, -73.93004681818182],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8eac36c2412b23fe8b3754f88afc8623 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_85f959f37e30a5e67db47d91ad35b3df);
#
#
#             var marker_6712874b5dfca0a7c59bdb554d2c57aa = L.marker(
#                 [40.819688, -73.915091],
#                 {}
#             ).addTo(map_85f959f37e30a5e67db47d91ad35b3df);
#
#
#             marker_6712874b5dfca0a7c59bdb554d2c57aa.bindTooltip(
#                 `&lt;div&gt;
#                      L1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_259eabaa509f54f47d41b9aa5d4a9762 = L.marker(
#                 [40.815421, -73.941761],
#                 {}
#             ).addTo(map_85f959f37e30a5e67db47d91ad35b3df);
#
#
#             marker_259eabaa509f54f47d41b9aa5d4a9762.bindTooltip(
#                 `&lt;div&gt;
#                      L2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bc2c8929f3e9b2c2253a60ea4f49c733 = L.marker(
#                 [40.764198, -73.910785],
#                 {}
#             ).addTo(map_85f959f37e30a5e67db47d91ad35b3df);
#
#
#             marker_bc2c8929f3e9b2c2253a60ea4f49c733.bindTooltip(
#                 `&lt;div&gt;
#                      L3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2a49e627738aaf2bc76c9bf16289ce60 = L.marker(
#                 [40.76879, -73.953285],
#                 {}
#             ).addTo(map_85f959f37e30a5e67db47d91ad35b3df);
#
#
#             marker_2a49e627738aaf2bc76c9bf16289ce60.bindTooltip(
#                 `&lt;div&gt;
#                      L4
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fe1e7be6805d7528dca659d1e647b187 = L.marker(
#                 [40.734851, -73.95295],
#                 {}
#             ).addTo(map_85f959f37e30a5e67db47d91ad35b3df);
#
#
#             marker_fe1e7be6805d7528dca659d1e647b187.bindTooltip(
#                 `&lt;div&gt;
#                      L5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_41ce87e4151e34e6b8b2355bf4a5ed9a = L.marker(
#                 [40.743613, -73.977998],
#                 {}
#             ).addTo(map_85f959f37e30a5e67db47d91ad35b3df);
#
#
#             marker_41ce87e4151e34e6b8b2355bf4a5ed9a.bindTooltip(
#                 `&lt;div&gt;
#                      L6
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_787465967d547b22e059abbd0decb6f9 = L.marker(
#                 [40.745313, -73.993793],
#                 {}
#             ).addTo(map_85f959f37e30a5e67db47d91ad35b3df);
#
#
#             marker_787465967d547b22e059abbd0decb6f9.bindTooltip(
#                 `&lt;div&gt;
#                      L7
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e47312b6551a5e7ab9f3b6c5793dace6 = L.marker(
#                 [40.662713, -73.946101],
#                 {}
#             ).addTo(map_85f959f37e30a5e67db47d91ad35b3df);
#
#
#             marker_e47312b6551a5e7ab9f3b6c5793dace6.bindTooltip(
#                 `&lt;div&gt;
#                      L8
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c2ed0e2a065eebe6018211a8b7b99288 = L.marker(
#                 [40.703761, -73.886496],
#                 {}
#             ).addTo(map_85f959f37e30a5e67db47d91ad35b3df);
#
#
#             marker_c2ed0e2a065eebe6018211a8b7b99288.bindTooltip(
#                 `&lt;div&gt;
#                      L9
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fa11319ac494456856e873640a945ee4 = L.marker(
#                 [40.71362, -73.943076],
#                 {}
#             ).addTo(map_85f959f37e30a5e67db47d91ad35b3df);
#
#
#             marker_fa11319ac494456856e873640a945ee4.bindToolt
